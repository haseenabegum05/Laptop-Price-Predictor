# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptop.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender  \
# 0           0   Apple  Ultrabook    13.3            0    1      Intel
# 1           1   Apple  Ultrabook    13.3            0    0      Intel
# 2           2      HP   Notebook    15.6            0    0      Intel
# 3           3   Apple  Ultrabook    15.4            0    1      Intel
# 4           4   Apple  Ultrabook    13.3            0    1      Intel
#
#   Cpu_Type  Ram  Storage (GB)   Storage Type Gpu_Vender  \
# 0  Core i5    8           128            SSD      Intel
# 1  Core i5    8           128  Flash Storage      Intel
# 2  Core i5    8           256            SSD      Intel
# 3  Core i7   16           512            SSD        AMD
# 4  Core i5    8           256            SSD      Intel
#
#                  Gpu_Type  Weight               OpSys  Price_euros
# 0  Iris Plus Graphics 640    1.37                 Mac      1339.69
# 1        HD Graphics 6000    1.34                 Mac       898.94
# ...

# %%
df.shape
# Out:
# (1303, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1303 non-null   int64
#  1   Company       1303 non-null   object
#  2   TypeName      1303 non-null   object
#  3   Inches        1303 non-null   float64
#  4   Touchscreen   1303 non-null   int64
#  5   Ips           1303 non-null   int64
#  6   Cpu_Vender    1303 non-null   object
#  7   Cpu_Type      1303 non-null   object
#  8   Ram           1303 non-null   int64
#  9   Storage (GB)  1303 non-null   int64
#  10  Storage Type  1303 non-null   object
#  11  Gpu_Vender    1303 non-null   object
#  12  Gpu_Type      1303 non-null   object
#  13  Weight        1303 non-null   float64
#  14  OpSys         1303 non-null   object
#  15  Price_euros   1303 non-null   float64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.0+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Company         0
# TypeName        0
# Inches          0
# Touchscreen     0
# Ips             0
# Cpu_Vender      0
# Cpu_Type        0
# Ram             0
# Storage (GB)    0
# Storage Type    0
# Gpu_Vender      0
# Gpu_Type        0
# Weight          0
# OpSys           0
# Price_euros     0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'Touchscreen', 'Ips',
#        'Cpu_Vender', 'Cpu_Type', 'Ram', 'Storage (GB)', 'Storage Type',
#        'Gpu_Vender', 'Gpu_Type', 'Weight', 'OpSys', 'Price_euros'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender Cpu_Type  Ram  \
# 0   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
# 1   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 2      HP   Notebook    15.6            0    0      Intel  Core i5    8
# 3   Apple  Ultrabook    15.4            0    1      Intel  Core i7   16
# 4   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# 3           512            SSD        AMD          Radeon Pro 455    1.83
# 4           256            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros
# 0                 Mac      1339.69
# ...

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Touchscreen', 'Ips', 'Cpu_Vender',
#        'Cpu_Type', 'Ram', 'Storage (GB)', 'Storage Type', 'Gpu_Vender',
#        'Gpu_Type', 'Weight', 'OpSys', 'Price_euros'],
#       dtype='object')
#   Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender Cpu_Type  Ram  \
# 0   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
# 1   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 2      HP   Notebook    15.6            0    0      Intel  Core i5    8
# 3   Apple  Ultrabook    15.4            0    1      Intel  Core i7   16
# 4   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender Cpu_Type  Ram  \
# 0   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
# 1   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 2      HP   Notebook    15.6            0    0      Intel  Core i5    8
# 3   Apple  Ultrabook    15.4            0    1      Intel  Core i7   16
# 4   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# 3           512            SSD        AMD          Radeon Pro 455    1.83
# 4           256            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros
# 0                 Mac      1339.69
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1303 non-null   object
#  1   TypeName      1303 non-null   object
#  2   Inches        1303 non-null   float64
#  3   Touchscreen   1303 non-null   int64
#  4   Ips           1303 non-null   int64
#  5   Cpu_Vender    1303 non-null   object
#  6   Cpu_Type      1303 non-null   object
#  7   Ram           1303 non-null   int32
#  8   Storage (GB)  1303 non-null   int64
#  9   Storage Type  1303 non-null   object
#  10  Gpu_Vender    1303 non-null   object
#  11  Gpu_Type      1303 non-null   object
#  12  Weight        1303 non-null   float32
#  13  OpSys         1303 non-null   object
#  14  Price_euros   1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(3), object(8)
# memory usage: 142.6+ KB

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df['Price_euros'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1748\2073861339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_euros'])
# <Axes: xlabel='Price_euros', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1748\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price_euros'>

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Touchscreen', 'Ips', 'Cpu_Vender',
#        'Cpu_Type', 'Ram', 'Storage (GB)', 'Storage Type', 'Gpu_Vender',
#        'Gpu_Type', 'Weight', 'OpSys', 'Price_euros'],
#       dtype='object')
#   Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender Cpu_Type  Ram  \
# 0   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
# 1   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 2      HP   Notebook    15.6            0    0      Intel  Core i5    8
# 3   Apple  Ultrabook    15.4            0    1      Intel  Core i7   16
# 4   Apple  Ultrabook    13.3            0    1      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# ...

# %%
df['Touchscreen'] = df['TypeName'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender  Cpu_Type  Ram  \
# 951     Dell  Ultrabook    14.0            0    0      Intel   Core i7    8
# 945   Lenovo     Gaming    15.6            0    1        AMD  FX 8800P   16
# 653      MSI     Gaming    15.6            0    0      Intel   Core i7    8
# 1091      HP   Notebook    15.6            0    0      Intel   Core i3    4
# 679     Acer     Gaming    15.6            0    0      Intel   Core i5   16
#
#       Storage (GB)    Storage Type Gpu_Vender             Gpu_Type  Weight  \
# 951            256             SSD      Intel      HD Graphics 620    1.36
# 945            512  SSD +  1TB HDD        AMD       Radeon R9 M385    2.50
# 653            128  SSD +  1TB HDD     Nvidia  GeForce GTX 1050 Ti    2.20
# 1091          1024             HDD      Intel      HD Graphics 520    1.86
# 679            256             SSD     Nvidia  GeForce GTX 1050 Ti    2.50
#
#                    OpSys  Price_euros
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price_euros'>

# %%
df['Ips'] = df['TypeName'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender Cpu_Type  Ram  \
# 0   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 1   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 2      HP   Notebook    15.6            0    0      Intel  Core i5    8
# 3   Apple  Ultrabook    15.4            0    0      Intel  Core i7   16
# 4   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# 3           512            SSD        AMD          Radeon Pro 455    1.83
# 4           256            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros
# 0                 Mac      1339.69
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price_euros'>

# %%
new = df['Touchscreen'] = df['TypeName'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#       Company            TypeName  Inches  Touchscreen  Ips Cpu_Vender  \
# 158      Dell  2 in 1 Convertible    15.6            0    0      Intel
# 1112   Lenovo            Notebook    15.6            0    0      Intel
# 1008       HP            Notebook    14.0            0    0      Intel
# 173   Toshiba            Notebook    15.6            0    0      Intel
# 390      Asus              Gaming    17.3            0    0      Intel
#
#      Cpu_Type  Ram  Storage (GB) Storage Type Gpu_Vender          Gpu_Type  \
# 158   Core i7    8           256          SSD      Intel  UHD Graphics 620
# 1112  Core i3    4           128          SSD      Intel   HD Graphics 520
# 1008  Core i5    8           256          SSD     Nvidia     GeForce 930MX
# 173   Core i3    4           500          HDD      Intel   HD Graphics 620
# 390   Core i7    8          1024          HDD     Nvidia  GeForce GTX 1050
#
#       Weight    OpSys  Price_euros  X_res  Y_res
# ...

# %%
df['X_res'] = df['X_res'].astype(str).str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0] if x else None)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender Cpu_Type  Ram  \
# 0   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 1   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
# 2      HP   Notebook    15.6            0    0      Intel  Core i5    8
# 3   Apple  Ultrabook    15.4            0    0      Intel  Core i7   16
# 4   Apple  Ultrabook    13.3            0    0      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# 3           512            SSD        AMD          Radeon Pro 455    1.83
# 4           256            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros X_res  Y_res
# ...

# %%
df['X_res'] = df['X_res'].fillna(0).astype(int)
df['Y_res'] = df['Y_res'].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1303 non-null   object
#  1   TypeName      1303 non-null   object
#  2   Inches        1303 non-null   float64
#  3   Touchscreen   1303 non-null   int64
#  4   Ips           1303 non-null   int64
#  5   Cpu_Vender    1303 non-null   object
#  6   Cpu_Type      1303 non-null   object
#  7   Ram           1303 non-null   int32
#  8   Storage (GB)  1303 non-null   int64
#  9   Storage Type  1303 non-null   object
#  10  Gpu_Vender    1303 non-null   object
#  11  Gpu_Type      1303 non-null   object
#  12  Weight        1303 non-null   float32
#  13  OpSys         1303 non-null   object
#  14  Price_euros   1303 non-null   float64
#  15  X_res         1303 non-null   int32
#  16  Y_res         1303 non-null   int32
# ...

# %%
df = pd.read_csv('laptop.csv')

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_columns.corr()
price_corr = correlation_matrix['Price_euros']

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5 / df['Inches']).astype(float)

# %%
correlation_matrix = numeric_columns.corr()
price_corr = correlation_matrix['Price_euros']

# %%
df.drop(columns=['Touchscreen'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ips Cpu_Vender Cpu_Type  Ram  \
# 0           0   Apple  Ultrabook    13.3    1      Intel  Core i5    8
# 1           1   Apple  Ultrabook    13.3    0      Intel  Core i5    8
# 2           2      HP   Notebook    15.6    0      Intel  Core i5    8
# 3           3   Apple  Ultrabook    15.4    1      Intel  Core i7   16
# 4           4   Apple  Ultrabook    13.3    1      Intel  Core i5    8
#
#    Storage (GB)   Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0           128            SSD      Intel  Iris Plus Graphics 640    1.37
# 1           128  Flash Storage      Intel        HD Graphics 6000    1.34
# 2           256            SSD      Intel         HD Graphics 620    1.86
# 3           512            SSD        AMD          Radeon Pro 455    1.83
# 4           256            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  X_res  Y_res  ppi
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Ram  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5    8           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5    8           128
# 2           2      HP   Notebook    0      Intel  Core i5    8           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7   16           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5    8           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi
# 0                 Mac      1339.69  0.0
# 1                 Mac       898.94  0.0
# ...

# %%
df['Cpu_Type'].value_counts()
df['Cpu_Vender'].value_counts()
# Out:
# Cpu_Vender
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
df['Cpu Name'] = df['Cpu_Type'].apply(lambda x:" ".join(x.split()[0:3]))
df['Cpu Name'] = df['Cpu_Vender'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Ram  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5    8           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5    8           128
# 2           2      HP   Notebook    0      Intel  Core i5    8           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7   16           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5    8           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi Cpu Name
# 0                 Mac      1339.69  0.0    Intel
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Ram  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5    8           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5    8           128
# 2           2      HP   Notebook    0      Intel  Core i5    8           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7   16           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5    8           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi Cpu Name              Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Ips', 'Cpu_Vender', 'Cpu_Type',
#        'Ram', 'Storage (GB)', 'Storage Type', 'Gpu_Vender', 'Gpu_Type',
#        'Weight', 'OpSys', 'Price_euros', 'ppi', 'Cpu Name', 'Cpu brand'],
#       dtype='object')

# %%
df.drop(columns=['Cpu Name', 'Cpu brand'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Ram  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5    8           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5    8           128
# 2           2      HP   Notebook    0      Intel  Core i5    8           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7   16           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5    8           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi
# 0                 Mac      1339.69  0.0
# 1                 Mac       898.94  0.0
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'] = df['Ram'].astype(str).replace('\.0', '', regex=True)
df["Ram"] = df["Ram"].str.replace('GB', '')
df["Ram"] = df["Ram"].str.replace('TB', '000')

new = df["Ram"].str.split("+", n=1, expand=True)

df["first"] = new[0].str.strip()
df["second"] = new[1].str.strip() if len(new.columns) > 1 else None

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)
df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace=True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"])

# Drop intermediate columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'], inplace=True)

# %%
df.sample(5)
# Out:
#       Unnamed: 0  Company   TypeName  Ips Cpu_Vender           Cpu_Type Ram  \
# 228          228     Asus   Notebook    0      Intel            Core i5   8
# 681          681     Asus   Notebook    0      Intel  Celeron Dual Core   4
# 1007        1007       HP  Ultrabook    0      Intel            Core i7   8
# 952          952  Toshiba   Notebook    0      Intel            Core i5   8
# 1119        1119     Asus     Gaming    0      Intel            Core i7   8
#
#       Storage (GB)      Storage Type Gpu_Vender          Gpu_Type  Weight  \
# 228            256  SSD +  500GB HDD     Nvidia  GeForce GTX 950M    2.69
# 681            128               SSD      Intel   HD Graphics 500    1.86
# 1007           256               SSD      Intel   HD Graphics 520    1.43
# 952            256               SSD      Intel   HD Graphics 520    1.20
# 1119           128    SSD +  1TB HDD     Nvidia  GeForce GTX 960M    3.52
#
# ...

# %%
df.drop(columns=['Ram'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5           128
# 2           2      HP   Notebook    0      Intel  Core i5           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi  HDD  SSD  Hybrid  Flash_Storage
# 0                 Mac      1339.69  0.0    0    0       0              0
# ...

# %%
correlation_matrix = numeric_columns.corr()
price_corr = correlation_matrix['Price_euros']

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5           128
# 2           2      HP   Notebook    0      Intel  Core i5           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi  HDD  SSD
# 0                 Mac      1339.69  0.0    0    0
# 1                 Mac       898.94  0.0    0    0
# ...

# %%
df['Gpu_Type'].value_counts()
# Out:
# Gpu_Type
# HD Graphics 620     281
# HD Graphics 520     185
# UHD Graphics 620     68
# GeForce GTX 1050     66
# GeForce GTX 1060     48
#                    ...
# Radeon R5 520         1
# Radeon R7             1
# HD Graphics 540       1
# Radeon 540            1
# Mali T860 MP4         1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu_Type'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5           128
# 2           2      HP   Notebook    0      Intel  Core i5           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5           256
#
#     Storage Type Gpu_Vender                Gpu_Type  Weight  \
# 0            SSD      Intel  Iris Plus Graphics 640    1.37
# 1  Flash Storage      Intel        HD Graphics 6000    1.34
# 2            SSD      Intel         HD Graphics 620    1.86
# 3            SSD        AMD          Radeon Pro 455    1.83
# 4            SSD      Intel  Iris Plus Graphics 650    1.37
#
#                 OpSys  Price_euros  ppi  HDD  SSD Gpu brand
# 0                 Mac      1339.69  0.0    0    0      Iris
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# HD            639
# GeForce       368
# Radeon        173
# UHD            68
# Quadro         31
# Iris           14
# FirePro         5
# R4              1
# GTX             1
# R17M-M1-70      1
# Graphics        1
# Mali            1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# HD            639
# GeForce       368
# Radeon        173
# UHD            68
# Quadro         31
# Iris           14
# FirePro         5
# R4              1
# GTX             1
# R17M-M1-70      1
# Graphics        1
# Mali            1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price_euros'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu_Type'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5           128
# 2           2      HP   Notebook    0      Intel  Core i5           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5           256
#
#     Storage Type Gpu_Vender  Weight               OpSys  Price_euros  ppi  \
# 0            SSD      Intel    1.37                 Mac      1339.69  0.0
# 1  Flash Storage      Intel    1.34                 Mac       898.94  0.0
# 2            SSD      Intel    1.86  Others/No OS/Linux       575.00  0.0
# 3            SSD        AMD    1.83                 Mac      2537.45  0.0
# 4            SSD      Intel    1.37                 Mac      1803.60  0.0
#
#    HDD  SSD Gpu brand
# 0    0    0      Iris
# 1    0    0        HD
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows               1125
# Others/No OS/Linux     157
# Mac                     21
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Ips Cpu_Vender Cpu_Type  Storage (GB)  \
# 0           0   Apple  Ultrabook    1      Intel  Core i5           128
# 1           1   Apple  Ultrabook    0      Intel  Core i5           128
# 2           2      HP   Notebook    0      Intel  Core i5           256
# 3           3   Apple  Ultrabook    1      Intel  Core i7           512
# 4           4   Apple  Ultrabook    1      Intel  Core i5           256
#
#     Storage Type Gpu_Vender  Weight               OpSys  Price_euros  ppi  \
# 0            SSD      Intel    1.37                 Mac      1339.69  0.0
# 1  Flash Storage      Intel    1.34                 Mac       898.94  0.0
# 2            SSD      Intel    1.86  Others/No OS/Linux       575.00  0.0
# 3            SSD        AMD    1.83                 Mac      2537.45  0.0
# 4            SSD      Intel    1.37                 Mac      1803.60  0.0
#
#    HDD  SSD Gpu brand                  os
# 0    0    0      Iris  Others/No OS/Linux
# ...

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1748\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price_euros'>

# %%
correlation_matrix = numeric_columns.corr()
price_corr = correlation_matrix['Price_euros']

# %%
sns.heatmap(numeric_columns.corr())
# Out:
# <Axes: >

# %%
sns.distplot(np.log(df['Price_euros']))
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1748\3038007691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price_euros']))
# <Axes: xlabel='Price_euros', ylabel='Density'>

# %%
X = df.drop(columns=['Price_euros'])
y = np.log(df['Price_euros'])

# %%
X
# Out:
#       Unnamed: 0 Company            TypeName  Ips Cpu_Vender  \
# 0              0   Apple           Ultrabook    1      Intel
# 1              1   Apple           Ultrabook    0      Intel
# 2              2      HP            Notebook    0      Intel
# 3              3   Apple           Ultrabook    1      Intel
# 4              4   Apple           Ultrabook    1      Intel
# ...          ...     ...                 ...  ...        ...
# 1298        1298  Lenovo  2 in 1 Convertible    1      Intel
# 1299        1299  Lenovo  2 in 1 Convertible    1      Intel
# 1300        1300  Lenovo            Notebook    0      Intel
# 1301        1301      HP            Notebook    0      Intel
# 1302        1302    Asus            Notebook    0      Intel
#
#                Cpu_Type  Storage (GB)   Storage Type Gpu_Vender  Weight  ppi  \
# 0               Core i5           128            SSD      Intel    1.37  0.0
# ...

# %%
y
# Out:
# 0       7.200194
# 1       6.801216
# 2       6.354370
# 3       7.838915
# 4       7.497540
#           ...
# 1298    6.458338
# 1299    7.312553
# 1300    5.433722
# 1301    6.638568
# 1302    5.910797
# Name: Price_euros, Length: 1303, dtype: float64
